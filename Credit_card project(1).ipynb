# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_customers=pd.read_csv(r"C:\Users\Nitin Agrawal\Downloads\customers.csv")
df_loans=pd.read_csv(r"C:\Users\Nitin Agrawal\Downloads\loans.csv")
df_bureau=pd.read_csv(r"C:\Users\Nitin Agrawal\Downloads\bureau_data.csv")

# %%
df_customers.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0         49340.0  444060           1973600                  33
# 1         77660.0  698940           3106400                  30
# 2         43400.0  390600           1736000                  21
# 3         34940.0  314460           1397600                   6
# 4         90400.0  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     24-07-2019
# 1                 709309                       464100     24-07-2019
# 2                1562399                      1476042     24-07-2019
# 3                1257839                      1031094     24-07-2019
# 4                1772334                      1032458     24-07-2019
#
#   installment_start_dt  default
# 0           10-08-2019    False
# 1           15-08-2019    False
# 2           21-08-2019    False
# 3           09-08-2019    False
# 4           02-08-2019    False

# %%
df=df_customers.merge(df_loans,on="cust_id")

# %%
df=df.merge(df_bureau,on="cust_id")

# %%
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     24-07-2019            10-08-2019   False                       1
# 1  ...     24-07-2019            15-08-2019   False                       3
# 2  ...     24-07-2019            21-08-2019   False                       2
# 3  ...     24-07-2019            09-08-2019   False                       3
# 4  ...     24-07-2019            02-08-2019   False                       4
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
# 3                         0                115                 15         87
# 4                         2                120                  0          0
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
# 3              5                        26
# 4              5                        10
#
# [5 rows x 33 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns="default"),df["default"], test_size=0.2, random_state=42)

# %%
df_train = pd.concat([X_train, y_train], axis="columns")
df_test = pd.concat([X_test, y_test], axis="columns")

# %%
df_train.isnull().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 53
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
mode_residance=df_train["residence_type"].mode()[0]
mode_residance
# Out:
# 'Owned'

# %%
df_train["residence_type"].fillna(mode_residance,inplace=True)

# %%
df_test["residence_type"].fillna(mode_residance,inplace=True)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %%
rows = (len(columns_continuous) + 2) // 3  # Adjust this depending on how you want to layout subplots
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))
axes = axes.flatten()  # Flatten in case of 2D array

for i, col in enumerate(columns_continuous):
    axes[i].boxplot(df[col])
    axes[i].set_title(col)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Create subplots
rows = ( len(columns_continuous)+2) // 3  # 3 columns per row
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))
axes = axes.flatten()

# Plot histogram for each column
for i, col in enumerate(columns_continuous):
    axes[i].hist(df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(f'Histogram of {col}')

# Hide unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
df_train['processing_fee'].describe()
# Out:
# count    4.000000e+04
# mean     8.082281e+04
# std      1.203019e+05
# min      0.000000e+00
# 25%      1.922000e+04
# 50%      4.472000e+04
# 75%      9.206500e+04
# max      5.698030e+06
# Name: processing_fee, dtype: float64

# %%
df_train[df_train["processing_fee"]>0.03*df_train['loan_amount']][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000     2669791.023
# 9898       3626000     5293543.524
# 47089      1738000     1858964.768
# 33705      3812000     5678020.859
# 12294      4639000     5698029.901
# 28174       966000     1214492.673
# 29305      2616000     3036378.005

# %%
df_train_1=df_train[df_train["processing_fee"]<0.03*df_train['loan_amount']].copy()

# %%
df_test=df_test[df_test["processing_fee"]<0.03*df_test['loan_amount']].copy()

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['F' 'M']
# marital_status --> ['Single' 'Married']
# employment_status --> ['Salaried' 'Self-Employed']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Lucknow' 'Delhi' 'Chennai' 'Jaipur' 'Pune' 'Bangalore' 'Kolkata'
#  'Hyderabad' 'Mumbai' 'Ahmedabad']
# state --> ['Uttar Pradesh' 'Delhi' 'Tamil Nadu' 'Rajasthan' 'Maharashtra'
#  'Karnataka' 'West Bengal' 'Telangana' 'Gujarat']
# zipcode --> [226001 110001 600001 302001 411001 560001 700001 500001 400001 380001]
# loan_purpose --> ['Personal' 'Home' 'Education' 'Auto' 'Personaal']
# loan_type --> ['Unsecured' 'Secured']
# default --> [False  True]

# %%
df_train_1["loan_purpose"].value_counts()
# Out:
# loan_purpose
# Personal     14013
# Home         12003
# Auto          7947
# Education     6006
# Personaal       18
# Name: count, dtype: int64

# %%
df_train_1["loan_purpose"]=df_train_1["loan_purpose"].replace("Personaal","Personal")

# %%
df_test["loan_purpose"]=df_test["loan_purpose"].replace("Personaal","Personal")

# %%
df_test["loan_purpose"].unique()
# Out:
# array(['Education', 'Home', 'Auto', 'Personal'], dtype=object)

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

# %%
rows = (len(columns_continuous) + 2) // 4  # Adjust this depending on how you want to layout subplots
fig, axes = plt.subplots(rows, 4, figsize=(24,20))
axes = axes.flatten()  # Flatten in case of 2D array
for i, col in enumerate(columns_continuous):
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True,ax=axes[i],label='default=0',legend=True)
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True,ax=axes[i], label='default=1',legend=True) 
    axes[i].legend()
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)
    
plt.tight_layout()
plt.show()

# %%
df_train_1["loan_to_income"]=round(df_train["loan_amount"]/df_train["income"],2)
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1[df_train_1["default"]==0]["loan_to_income"],fill=True,label="default0")
sns.kdeplot(df_train_1[df_train_1["default"]==1]["loan_to_income"],fill=True,label="default1")
plt.legend()
plt.show()

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)
df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
numeric_columns=df_train_3.select_dtypes(["int64","float64"]).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
X_train[numeric_columns]=scalar.fit_transform(X_train[numeric_columns])
X_train.describe()
# Out:
#                 age  number_of_dependants  years_at_current_address  \
# count  39987.000000          39987.000000              39987.000000
# mean       0.414455              0.387931                  0.499652
# std        0.189549              0.307152                  0.297852
# min        0.000000              0.000000                  0.000000
# 25%        0.288462              0.000000                  0.233333
# 50%        0.423077              0.400000                  0.500000
# 75%        0.538462              0.600000                  0.766667
# max        1.000000              1.000000                  1.000000
#
#             zipcode  sanction_amount  processing_fee           gst  \
# count  39987.000000     39987.000000    39987.000000  39987.000000
# mean       0.523507         0.089166        0.082912      0.082912
# std        0.286229         0.121042        0.113346      0.113346
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.325424         0.020526        0.019092      0.019092
# 50%        0.491525         0.049516        0.045762      0.045762
# 75%        0.762712         0.097728        0.095292      0.095292
# max        1.000000         1.000000        1.000000      1.000000
#
#        net_disbursement  loan_tenure_months  principal_outstanding  \
# count      39987.000000        39987.000000           39987.000000
# mean           0.082912            0.375274               0.262157
# std            0.113346            0.234365               0.244575
# min            0.000000            0.000000               0.000000
# 25%            0.019092            0.188679               0.078398
# 50%            0.045762            0.339623               0.194448
# 75%            0.095292            0.547170               0.353496
# max            1.000000            1.000000               1.000000
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                 39987.000000             39987.000000
# mean                      0.123793                 0.498395
# std                       0.133492                 0.372459
# min                       0.000000                 0.000000
# 25%                       0.034193                 0.000000
# 50%                       0.082960                 0.333333
# 75%                       0.155692                 0.666667
# max                       1.000000                 1.000000
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# count               39987.000000   39987.000000              39987.000000
# mean                    0.499525       0.500247                  0.437640
# std                     0.407226       0.253385                  0.296587
# min                     0.000000       0.000000                  0.000000
# 25%                     0.000000       0.375000                  0.181818
# 50%                     0.500000       0.500000                  0.393939
# 75%                     1.000000       0.625000                  0.676768
# max                     1.000000       1.000000                  1.000000
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# count    39987.000000       39987.000000             39987.000000
# mean         0.293701           0.104261                 0.330414
# std          0.227745           0.172853                 0.290297
# min          0.000000           0.000000                 0.000000
# 25%          0.110070           0.000000                 0.000000
# 50%          0.201405           0.038000                 0.430000
# 75%          0.503513           0.132000                 0.580000
# max          1.000000           1.000000                 1.000000

# %%
X_test= df_test.drop('default', axis='columns')
y_test = df_test['default']
X_test[numeric_columns]=scalar.transform(X_test[numeric_columns])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(data):
    vif_data = pd.DataFrame()
    vif_data["feature"] = data.columns
    vif_data["VIF"] =[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_data

# %%
numeric_columns=X_train_1.select_dtypes(["int64","float64"]).columns
calculate_vif(X_train_1[numeric_columns])
# Out:
#                         feature       VIF
# 0                           age  5.444378
# 1          number_of_dependants  2.724387
# 2      years_at_current_address  3.408094
# 3                       zipcode  3.774905
# 4            loan_tenure_months  5.973497
# 5   bank_balance_at_application  1.802872
# 6       number_of_open_accounts  4.324655
# 7     number_of_closed_accounts  2.361267
# 8                 enquiry_count  6.358410
# 9      credit_utilization_ratio  2.914252
# 10               loan_to_income  4.519208
# 11            delinquency_ratio  1.947692
# 12      avg_dpd_per_delinquency  2.931525

# %%
X_train_1=X_train.drop(columns=['processing_fee', 'gst', 'net_disbursement',"principal_outstanding","sanction_amount"],axis=1)
X_train_1.head()
# Out:
#             age gender marital_status employment_status  number_of_dependants  \
# 39087  0.211538      F         Single          Salaried                   0.4
# 30893  0.346154      F        Married     Self-Employed                   0.8
# 45278  0.326923      M        Married          Salaried                   0.6
# 16398  0.596154      M        Married     Self-Employed                   0.6
# 13653  0.365385      M         Single          Salaried                   0.0
#
#       residence_type  years_at_current_address     city          state  \
# 39087          Owned                  0.033333  Lucknow  Uttar Pradesh
# 30893       Mortgage                  0.800000    Delhi          Delhi
# 45278          Owned                  0.866667  Chennai     Tamil Nadu
# 16398         Rented                  0.200000  Chennai     Tamil Nadu
# 13653          Owned                  0.500000  Chennai     Tamil Nadu
#
#         zipcode  ...  loan_type loan_tenure_months  \
# 39087  0.196610  ...  Unsecured           0.283019
# 30893  0.000000  ...    Secured           0.452830
# 45278  0.830508  ...    Secured           0.433962
# 16398  0.830508  ...  Unsecured           0.207547
# 13653  0.830508  ...    Secured           0.584906
#
#        bank_balance_at_application  number_of_open_accounts  \
# 39087                     0.025975                 0.666667
# 30893                     0.156704                 0.666667
# 45278                     0.170276                 0.666667
# 16398                     0.206666                 0.333333
# 13653                     0.013898                 1.000000
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 39087                        1.0          0.500                  0.929293
# 30893                        1.0          0.250                  0.535354
# 45278                        1.0          0.250                  0.050505
# 16398                        0.0          0.500                  0.161616
# 13653                        0.5          0.375                  0.111111
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 39087        0.135831              0.000                     0.00
# 30893        0.742389              0.128                     0.70
# 45278        0.601874              0.015                     0.50
# 16398        0.081967              0.000                     0.00
# 13653        0.332553              0.050                     0.66
#
# [5 rows x 21 columns]

# %%
def calculate_iv(df,feature,target):
    grouped=df.groupby(feature)[target].agg(["count","sum"])
    grouped.rename(columns={"count":"total","sum":"good"},inplace=True)
    grouped["bad"]=grouped["total"]-grouped["good"]
    grouped["good_pct"]=grouped["good"]/grouped["good"].sum()
    grouped["bad_pct"]=grouped["bad"]/grouped["bad"].sum()
    grouped["woe"]=np.log( grouped["good_pct"]/grouped["bad_pct"])
    grouped["iv"]= grouped["woe"]*(grouped["good_pct"]-grouped["bad_pct"])
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    total_iv = grouped['iv'].sum()
    return total_iv

# %%
iv_values={}
for feature in X_train_1.columns:
    if X_train_1[feature].dtype=="object":
        iv=calculate_iv(pd.concat([X_train_1,y_train],axis=1),feature,"default")
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        iv = calculate_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature]=iv
iv_values
# Out:
# {'age': 0.07668845616983133,
#  'gender': 0.0005252221534668387,
#  'marital_status': 0.0017548924448790612,
#  'employment_status': 0.0025063248599747653,
#  'number_of_dependants': 0.002977979675793198,
#  'residence_type': 0.2544613313080765,
#  'years_at_current_address': 0.001383430766914449,
#  'city': 0.0006329995470511145,
#  'state': 0.0006284621608370921,
#  'zipcode': 0.0006324964364876762,
#  'loan_purpose': 0.3872402817840378,
#  'loan_type': 0.16888218833539492,
#  'loan_tenure_months': 0.23017122426003067,
#  'bank_balance_at_application': 0.005320756307500039,
#  'number_of_open_accounts': 0.0780671613772511,
#  'number_of_closed_accounts': 0.0003744080466105261,
#  'enquiry_count': 0.005561748920422708,
#  'credit_utilization_ratio': 2.4265085265949526,
#  'loan_to_income': 0.48823891855073287,
#  'delinquency_ratio': 0.678042778646962,
#  'avg_dpd_per_delinquency': 0.40737964919244773}

# %%
iv_df=pd.DataFrame(iv_values.items(),columns=["feature","iv"])
iv_df
# Out:
#                         feature        iv
# 0                           age  0.076688
# 1                        gender  0.000525
# 2                marital_status  0.001755
# 3             employment_status  0.002506
# 4          number_of_dependants  0.002978
# 5                residence_type  0.254461
# 6      years_at_current_address  0.001383
# 7                          city  0.000633
# 8                         state  0.000628
# 9                       zipcode  0.000632
# 10                 loan_purpose  0.387240
# 11                    loan_type  0.168882
# 12           loan_tenure_months  0.230171
# 13  bank_balance_at_application  0.005321
# 14      number_of_open_accounts  0.078067
# 15    number_of_closed_accounts  0.000374
# 16                enquiry_count  0.005562
# 17     credit_utilization_ratio  2.426509
# 18               loan_to_income  0.488239
# 19            delinquency_ratio  0.678043
# 20      avg_dpd_per_delinquency  0.407380

# %%
selected_features=[]
selected_features = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %%
X_train_reduced = X_train_1[selected_features]
X_test_reduced = X_test[selected_features]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#             age  loan_tenure_months  number_of_open_accounts  \
# 39087  0.211538            0.283019                 0.666667
# 30893  0.346154            0.452830                 0.666667
# 45278  0.326923            0.433962                 0.666667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 39087                  0.929293        0.135831              0.000
# 30893                  0.535354        0.742389              0.128
# 45278                  0.050505        0.601874              0.015
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 39087                      0.0                  True                  False
# 30893                      0.7                 False                  False
# 45278                      0.5                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 39087                   False              False                   True
# 30893                   False               True                  False
# 45278                   False               True                  False
#
#        loan_type_Unsecured
# 39087                 True
# 30893                False
# 45278                False

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#             age  loan_tenure_months  number_of_open_accounts  \
# 33553  0.346154            0.528302                 0.333333
# 9427   0.288462            0.622642                 1.000000
# 199    0.192308            0.622642                 1.000000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 33553                  0.121212        0.257611              0.043
# 9427                   0.858586        0.688525              0.000
# 199                    0.727273        0.634660              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 33553                      0.9                  True                  False
# 9427                       0.0                  True                  False
# 199                        0.0                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 33553                    True              False                  False
# 9427                    False               True                  False
# 199                     False               True                  False
#
#        loan_type_Unsecured
# 33553                False
# 9427                 False
# 199                  False

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98      9137
#         True       0.83      0.72      0.77       861
#
#     accuracy                           0.96      9998
#    macro avg       0.90      0.85      0.88      9998
# weighted avg       0.96      0.96      0.96      9998

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98      9137
#         True       0.83      0.70      0.76       861
#
#     accuracy                           0.96      9998
#    macro avg       0.90      0.84      0.87      9998
# weighted avg       0.96      0.96      0.96      9998

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      9137
#         True       0.80      0.74      0.77       861
#
#     accuracy                           0.96      9998
#    macro avg       0.89      0.86      0.87      9998
# weighted avg       0.96      0.96      0.96      9998

# %%
from sklearn.model_selection import RandomizedSearchCV
log_reg=LogisticRegression(max_iter=1000)
param_grid={'C': np.logspace(-4, 4, 20), "solver":["newton-cg", "sag","lbfgs"]}
random_search=RandomizedSearchCV(log_reg,param_distributions=param_grid,n_iter=50, scoring='f1', n_jobs=-1,cv=3,verbose=2,random_state=42)
random_search.fit(X_train_encoded, y_train)
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
best_model = random_search.best_estimator_
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'lbfgs', 'C': 78.47599703514607}
# Best Score: 0.7643853197302403

# %%
y_pred=best_model.predict(X_test_encoded)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      9137
#         True       0.81      0.74      0.77       861
#
#     accuracy                           0.96      9998
#    macro avg       0.89      0.86      0.88      9998
# weighted avg       0.96      0.96      0.96      9998

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

# %%
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 best_model = random_search.best_estimator_
#       2 y_pred = best_model.predict(X_test_encoded)
#       3 print("Classification Report:")
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_estimator_'

# %%
from imblearn.under_sampling import RandomUnderSampler
rus=RandomUnderSampler(random_state=42)
X_train_res,y_train_res=rus.fit_resample(X_train_encoded,y_train)

# %%
y_train_res.value_counts()

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# False    36475
# True     36475
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    param={'C':trial.suggest_float('C', 1e-4, 1e4, log=True),
    'solver':trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),
    'tol':trial.suggest_float('tol', 1e-6, 1e-1, log=True),
    'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])}
    model = LogisticRegression(**param, max_iter=10000)
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    return np.mean(scores)

# %%
study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2025-06-19 11:01:39,497] A new study created in memory with name: no-name-f79a8bf2-ee48-48be-ab4c-54919477ba4c
# [I 2025-06-19 11:01:41,921] Trial 0 finished with value: 0.9121091765095866 and parameters: {'C': 0.0018438717239070534, 'solver': 'newton-cg', 'tol': 0.0262882054218207, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9121091765095866.
# [I 2025-06-19 11:01:43,315] Trial 1 finished with value: 0.8327560246347424 and parameters: {'C': 0.0003293068228852536, 'solver': 'liblinear', 'tol': 1.2806155885563414e-05, 'class_weight': None}. Best is trial 0 with value: 0.9121091765095866.
# [I 2025-06-19 11:01:45,361] Trial 2 finished with value: 0.9441261812465357 and parameters: {'C': 151.47776065342018, 'solver': 'newton-cg', 'tol': 1.2060537145419016e-06, 'class_weight': None}. Best is trial 2 with value: 0.9441261812465357.
# [I 2025-06-19 11:01:45,579] Trial 3 finished with value: 0.9442750884384038 and parameters: {'C': 166.6338064883452, 'solver': 'saga', 'tol': 0.009745030277690137, 'class_weight': None}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:45,753] Trial 4 finished with value: 0.8257486866963754 and parameters: {'C': 0.00011383119607867759, 'solver': 'lbfgs', 'tol': 1.0348397091386715e-06, 'class_weight': None}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:46,001] Trial 5 finished with value: 0.9324555652738898 and parameters: {'C': 0.01905636845436957, 'solver': 'saga', 'tol': 0.002337830441664276, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:46,173] Trial 6 finished with value: 0.8774564928974528 and parameters: {'C': 0.00046233730805050443, 'solver': 'lbfgs', 'tol': 0.03259070979894693, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:46,503] Trial 7 finished with value: 0.9441673916392022 and parameters: {'C': 788.0095759207953, 'solver': 'saga', 'tol': 0.0005517030025674007, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:46,800] Trial 8 finished with value: 0.9381445489310759 and parameters: {'C': 0.1107372494074733, 'solver': 'liblinear', 'tol': 1.687181011054407e-05, 'class_weight': None}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:01:47,348] Trial 9 finished with value: 0.9441123185545662 and parameters: {'C': 15.309156904614516, 'solver': 'saga', 'tol': 1.7597616229661033e-06, 'class_weight': None}. Best is trial 3 with value: 0.9442750884384038.
# [I 2025-06-19 11:02:03,822] Trial 49 finished with value: 0.9442323696033178 and parameters: {'C': 350.3573894778044, 'solver': 'liblinear', 'tol': 0.012900517205134932, 'class_weight': 'balanced'}. Best is trial 25 with value: 0.9443146498700677.

# %%
study_logistic .best_params
# Out:
# {'C': 40.51488047924929,
#  'solver': 'liblinear',
#  'tol': 0.0111978533083954,
#  'class_weight': None}

# %%
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.93      0.96      9137
#         True       0.55      0.94      0.70       861
#
#     accuracy                           0.93      9998
#    macro avg       0.77      0.94      0.83      9998
# weighted avg       0.96      0.93      0.94      9998

# %%
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }
    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2025-06-19 11:02:04,155] A new study created in memory with name: no-name-220118c4-78ab-44c4-b9cc-fedb47e86c4f
# [I 2025-06-19 11:02:05,391] Trial 0 finished with value: 0.9300008882888763 and parameters: {'lambda': 1.2262666619004212, 'alpha': 0.3525206219415947, 'subsample': 0.4573662476237824, 'colsample_bytree': 0.46480510609423337, 'max_depth': 7, 'eta': 0.06432043495553726, 'gamma': 8.487793905495252, 'scale_pos_weight': 9.218529122314157, 'min_child_weight': 3, 'max_delta_step': 9}. Best is trial 0 with value: 0.9300008882888763.
# [I 2025-06-19 11:02:06,669] Trial 1 finished with value: 0.9673184815980626 and parameters: {'lambda': 0.004065606492316832, 'alpha': 0.07129807513611511, 'subsample': 0.9575726448025925, 'colsample_bytree': 0.8416504397395321, 'max_depth': 7, 'eta': 0.15298793819726977, 'gamma': 0.2881668343935606, 'scale_pos_weight': 8.745303782497658, 'min_child_weight': 6, 'max_delta_step': 4}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:07,954] Trial 2 finished with value: 0.9596816593833353 and parameters: {'lambda': 0.074075300094773, 'alpha': 0.1308721446550513, 'subsample': 0.5994876227061989, 'colsample_bytree': 0.9790904934216121, 'max_depth': 6, 'eta': 0.09863070633586468, 'gamma': 4.0224274699193865, 'scale_pos_weight': 4.870158527850675, 'min_child_weight': 7, 'max_delta_step': 1}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:08,900] Trial 3 finished with value: 0.9579768158779242 and parameters: {'lambda': 0.1332010894487054, 'alpha': 3.9724427547729197, 'subsample': 0.6433748315163272, 'colsample_bytree': 0.4147546987949652, 'max_depth': 4, 'eta': 0.2012287006698984, 'gamma': 7.902754176972891, 'scale_pos_weight': 2.7745611057556276, 'min_child_weight': 1, 'max_delta_step': 7}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:09,932] Trial 4 finished with value: 0.936172376963737 and parameters: {'lambda': 7.339567607440907, 'alpha': 2.0802407813795227, 'subsample': 0.5437787464625284, 'colsample_bytree': 0.4269089271737719, 'max_depth': 6, 'eta': 0.09379347932117561, 'gamma': 9.507306718628572, 'scale_pos_weight': 6.1127858759800375, 'min_child_weight': 10, 'max_delta_step': 9}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:11,380] Trial 5 finished with value: 0.9552894018767719 and parameters: {'lambda': 0.10273593420482495, 'alpha': 0.0010793682669337085, 'subsample': 0.7005554253352131, 'colsample_bytree': 0.5201876306576512, 'max_depth': 8, 'eta': 0.04032870416446623, 'gamma': 0.19983297633916153, 'scale_pos_weight': 1.9897326012637526, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:12,447] Trial 6 finished with value: 0.9379400808527377 and parameters: {'lambda': 0.0011291007455478095, 'alpha': 0.9582170684425929, 'subsample': 0.5038016784267348, 'colsample_bytree': 0.5155091265691893, 'max_depth': 4, 'eta': 0.08262756081438408, 'gamma': 5.295492186027816, 'scale_pos_weight': 3.3737982647004605, 'min_child_weight': 6, 'max_delta_step': 1}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:13,648] Trial 7 finished with value: 0.9563741828937502 and parameters: {'lambda': 0.012417586094471926, 'alpha': 0.9096738766251907, 'subsample': 0.7194589426372175, 'colsample_bytree': 0.4051907052366147, 'max_depth': 6, 'eta': 0.16240656403823395, 'gamma': 0.9973496165009565, 'scale_pos_weight': 8.382252878717072, 'min_child_weight': 1, 'max_delta_step': 6}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:15,111] Trial 8 finished with value: 0.959914019078061 and parameters: {'lambda': 0.23598232778207137, 'alpha': 5.41355106437994, 'subsample': 0.7618025844687966, 'colsample_bytree': 0.9096726468155053, 'max_depth': 10, 'eta': 0.0966560049422646, 'gamma': 7.993971601786447, 'scale_pos_weight': 6.7536950809905, 'min_child_weight': 2, 'max_delta_step': 0}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:16,275] Trial 9 finished with value: 0.9529382954866309 and parameters: {'lambda': 0.07103194143156488, 'alpha': 0.013646269109078811, 'subsample': 0.5352879399784485, 'colsample_bytree': 0.4383704732390485, 'max_depth': 9, 'eta': 0.1398811427404352, 'gamma': 8.211369234714883, 'scale_pos_weight': 8.861642370926686, 'min_child_weight': 9, 'max_delta_step': 0}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:17,160] Trial 10 finished with value: 0.9515208040113552 and parameters: {'lambda': 0.0010596127520755977, 'alpha': 0.020833482582328783, 'subsample': 0.993673955196173, 'colsample_bytree': 0.7654899510090382, 'max_depth': 3, 'eta': 0.29207667085495215, 'gamma': 2.533830867355315, 'scale_pos_weight': 7.255979568287969, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:18,407] Trial 11 finished with value: 0.9654885723457026 and parameters: {'lambda': 0.010153447359238142, 'alpha': 9.00276133993999, 'subsample': 0.9377771204146866, 'colsample_bytree': 0.8934083196994691, 'max_depth': 10, 'eta': 0.20482767817365838, 'gamma': 6.024293952508794, 'scale_pos_weight': 6.883273041106849, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 1 with value: 0.9673184815980626.
# [I 2025-06-19 11:02:19,507] Trial 12 finished with value: 0.9690388828977499 and parameters: {'lambda': 0.007543894641112912, 'alpha': 0.031296507925247755, 'subsample': 0.9309379870893028, 'colsample_bytree': 0.8252646477662985, 'max_depth': 10, 'eta': 0.22843518784271447, 'gamma': 5.79168331336556, 'scale_pos_weight': 4.574520673667289, 'min_child_weight': 5, 'max_delta_step': 4}. Best is trial 12 with value: 0.9690388828977499.
# [I 2025-06-19 11:02:20,637] Trial 13 finished with value: 0.9710192434818755 and parameters: {'lambda': 0.008410906261066827, 'alpha': 0.017203908217867863, 'subsample': 0.8473221325196553, 'colsample_bytree': 0.732775508777629, 'max_depth': 8, 'eta': 0.2681263399737482, 'gamma': 3.6444310255572474, 'scale_pos_weight': 4.435792032054415, 'min_child_weight': 5, 'max_delta_step': 3}. Best is trial 13 with value: 0.9710192434818755.
# [I 2025-06-19 11:02:21,738] Trial 14 finished with value: 0.9715408677061088 and parameters: {'lambda': 0.01441846040888962, 'alpha': 0.007032821746267573, 'subsample': 0.850698428264774, 'colsample_bytree': 0.6837579593117167, 'max_depth': 9, 'eta': 0.2960919950599507, 'gamma': 3.3455475011983817, 'scale_pos_weight': 4.611037442792916, 'min_child_weight': 5, 'max_delta_step': 3}. Best is trial 14 with value: 0.9715408677061088.
# [I 2025-06-19 11:02:22,769] Trial 15 finished with value: 0.9710479766289222 and parameters: {'lambda': 0.024799602417406905, 'alpha': 0.003931809003112443, 'subsample': 0.8317106775407592, 'colsample_bytree': 0.6836139572601406, 'max_depth': 8, 'eta': 0.28168435891051574, 'gamma': 3.4328385391438694, 'scale_pos_weight': 3.7854519031227047, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 14 with value: 0.9715408677061088.
# [I 2025-06-19 11:02:23,919] Trial 16 finished with value: 0.9725179924539452 and parameters: {'lambda': 0.029889138391082797, 'alpha': 0.0027056341818921838, 'subsample': 0.829437741507665, 'colsample_bytree': 0.6401871523341566, 'max_depth': 8, 'eta': 0.25700533285793037, 'gamma': 2.235296681584071, 'scale_pos_weight': 3.4174770008532493, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 16 with value: 0.9725179924539452.
# [I 2025-06-19 11:02:25,151] Trial 17 finished with value: 0.9737131254093289 and parameters: {'lambda': 0.4865521257354782, 'alpha': 0.0033250467561029826, 'subsample': 0.8465862765530227, 'colsample_bytree': 0.6343128310230873, 'max_depth': 9, 'eta': 0.24896718460949613, 'gamma': 1.943550433020771, 'scale_pos_weight': 2.337589072547679, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 17 with value: 0.9737131254093289.
# [I 2025-06-19 11:02:26,365] Trial 18 finished with value: 0.9743603022753463 and parameters: {'lambda': 0.5666003292068454, 'alpha': 0.0014723948944984865, 'subsample': 0.7922703888306805, 'colsample_bytree': 0.6039692994264024, 'max_depth': 9, 'eta': 0.25434039481392057, 'gamma': 1.73516203806438, 'scale_pos_weight': 1.329159767732876, 'min_child_weight': 10, 'max_delta_step': 2}. Best is trial 18 with value: 0.9743603022753463.
# [I 2025-06-19 11:02:27,630] Trial 19 finished with value: 0.9740448096748234 and parameters: {'lambda': 0.6361665313787482, 'alpha': 0.0018510942575824018, 'subsample': 0.7799963941776009, 'colsample_bytree': 0.6110164008850973, 'max_depth': 9, 'eta': 0.2434432530176327, 'gamma': 1.2191146991853588, 'scale_pos_weight': 1.0394005744546497, 'min_child_weight': 9, 'max_delta_step': 6}. Best is trial 18 with value: 0.9743603022753463.
# [I 2025-06-19 11:02:28,964] Trial 20 finished with value: 0.9743738348116895 and parameters: {'lambda': 2.383565636173437, 'alpha': 0.0012641280905446243, 'subsample': 0.766823742840853, 'colsample_bytree': 0.5768467270506051, 'max_depth': 9, 'eta': 0.1898112621031516, 'gamma': 1.3411756624662015, 'scale_pos_weight': 1.2893378338486938, 'min_child_weight': 10, 'max_delta_step': 6}. Best is trial 20 with value: 0.9743738348116895.
# [I 2025-06-19 11:02:30,365] Trial 21 finished with value: 0.9743057811012692 and parameters: {'lambda': 2.43712715058831, 'alpha': 0.0011688048659003664, 'subsample': 0.7712425197853262, 'colsample_bytree': 0.5639127682510581, 'max_depth': 9, 'eta': 0.19878643409130153, 'gamma': 1.2052821488247072, 'scale_pos_weight': 1.1369306703354884, 'min_child_weight': 10, 'max_delta_step': 6}. Best is trial 20 with value: 0.9743738348116895.
# [I 2025-06-19 11:02:31,745] Trial 22 finished with value: 0.9738260321415716 and parameters: {'lambda': 2.9982207260221334, 'alpha': 0.0012110303200031371, 'subsample': 0.6575507461191546, 'colsample_bytree': 0.563352833424804, 'max_depth': 10, 'eta': 0.18859101531792938, 'gamma': 1.3591348857523218, 'scale_pos_weight': 1.166561744949008, 'min_child_weight': 10, 'max_delta_step': 6}. Best is trial 20 with value: 0.9743738348116895.
# [I 2025-06-19 11:02:43,695] Trial 30 finished with value: 0.9626858306918221 and parameters: {'lambda': 4.717780891777628, 'alpha': 0.002621549767959227, 'subsample': 0.6250764699474256, 'colsample_bytree': 0.5568981681044376, 'max_depth': 7, 'eta': 0.17759887063180693, 'gamma': 7.1638324101748, 'scale_pos_weight': 3.9232640381622286, 'min_child_weight': 10, 'max_delta_step': 7}. Best is trial 28 with value: 0.9749218739996331.
# [I 2025-06-19 11:02:45,255] Trial 31 finished with value: 0.9747162579847054 and parameters: {'lambda': 1.4359595953384168, 'alpha': 0.001978469346574443, 'subsample': 0.5945479911136342, 'colsample_bytree': 0.6013167415114218, 'max_depth': 10, 'eta': 0.2659828130823162, 'gamma': 0.7697481114814717, 'scale_pos_weight': 1.6016679038493282, 'min_child_weight': 10, 'max_delta_step': 8}. Best is trial 28 with value: 0.9749218739996331.
# [I 2025-06-19 11:02:46,816] Trial 32 finished with value: 0.9754982215018541 and parameters: {'lambda': 1.308540457255761, 'alpha': 0.0022258434103594165, 'subsample': 0.593894271934728, 'colsample_bytree': 0.7077435783827827, 'max_depth': 10, 'eta': 0.2761817069468113, 'gamma': 0.4707485146451856, 'scale_pos_weight': 1.5969197430167918, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 32 with value: 0.9754982215018541.
# [I 2025-06-19 11:02:48,336] Trial 33 finished with value: 0.9752785557363373 and parameters: {'lambda': 1.0606272836603663, 'alpha': 0.007814587132363918, 'subsample': 0.5854851148059268, 'colsample_bytree': 0.7226729545373541, 'max_depth': 10, 'eta': 0.2737512766671686, 'gamma': 0.40278635957624326, 'scale_pos_weight': 1.9952944064053288, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 32 with value: 0.9754982215018541.
# [I 2025-06-19 11:02:49,845] Trial 34 finished with value: 0.9755248755340329 and parameters: {'lambda': 1.0742218620230455, 'alpha': 0.0022685278774660787, 'subsample': 0.5903195399686537, 'colsample_bytree': 0.7148200781507773, 'max_depth': 10, 'eta': 0.2791590372263985, 'gamma': 0.6570815499235374, 'scale_pos_weight': 2.3939207026119806, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:51,491] Trial 35 finished with value: 0.9749488780730777 and parameters: {'lambda': 0.2363156259744132, 'alpha': 0.00433004773945581, 'subsample': 0.5789145354815654, 'colsample_bytree': 0.761663362358896, 'max_depth': 10, 'eta': 0.27521899302033676, 'gamma': 0.39270218807126167, 'scale_pos_weight': 2.433273408227656, 'min_child_weight': 8, 'max_delta_step': 10}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:53,008] Trial 36 finished with value: 0.9750997915128835 and parameters: {'lambda': 1.0125050602745638, 'alpha': 0.07672206304872281, 'subsample': 0.5664447562755763, 'colsample_bytree': 0.7625680122283487, 'max_depth': 10, 'eta': 0.27839467991870853, 'gamma': 0.5313500866494165, 'scale_pos_weight': 2.576654033544731, 'min_child_weight': 7, 'max_delta_step': 10}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:54,285] Trial 37 finished with value: 0.9725989123172968 and parameters: {'lambda': 0.9472879262859605, 'alpha': 0.10374345726611683, 'subsample': 0.4811698404515169, 'colsample_bytree': 0.8195827496158197, 'max_depth': 10, 'eta': 0.2975138629620545, 'gamma': 2.7215532219825116, 'scale_pos_weight': 5.348599194105368, 'min_child_weight': 7, 'max_delta_step': 9}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:55,455] Trial 38 finished with value: 0.9228412689126756 and parameters: {'lambda': 1.1896175233380208, 'alpha': 0.275701869939106, 'subsample': 0.5588788155946859, 'colsample_bytree': 0.7245673800382342, 'max_depth': 5, 'eta': 0.022769741852667003, 'gamma': 0.027093463117027206, 'scale_pos_weight': 3.2012520586320394, 'min_child_weight': 6, 'max_delta_step': 9}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:57,203] Trial 39 finished with value: 0.9736145396767034 and parameters: {'lambda': 9.881363925877539, 'alpha': 0.05538360344235165, 'subsample': 0.5124741727390966, 'colsample_bytree': 0.7851149651958989, 'max_depth': 10, 'eta': 0.2826815956261349, 'gamma': 0.6654696084980524, 'scale_pos_weight': 3.939081073621164, 'min_child_weight': 7, 'max_delta_step': 10}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:58,667] Trial 40 finished with value: 0.9720655962046977 and parameters: {'lambda': 4.677827917593023, 'alpha': 0.513583965735975, 'subsample': 0.41828680624795017, 'colsample_bytree': 0.8598874741756073, 'max_depth': 8, 'eta': 0.24142866038094377, 'gamma': 2.063694775915967, 'scale_pos_weight': 2.2946078453394394, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:02:59,655] Trial 41 finished with value: 0.9660331190300065 and parameters: {'lambda': 0.13102894166247617, 'alpha': 0.004347546083831033, 'subsample': 0.5703338787926774, 'colsample_bytree': 0.7686077051324945, 'max_depth': 10, 'eta': 0.27644825182907246, 'gamma': 9.992029392755363, 'scale_pos_weight': 2.6445792746908494, 'min_child_weight': 8, 'max_delta_step': 10}. Best is trial 34 with value: 0.9755248755340329.
# [I 2025-06-19 11:03:01,549] Trial 42 finished with value: 0.9756758431958836 and parameters: {'lambda': 0.38851425387553845, 'alpha': 0.027696949913200465, 'subsample': 0.5846993507485025, 'colsample_bytree': 0.7165887609264633, 'max_depth': 10, 'eta': 0.26860050215368664, 'gamma': 0.5775065190716857, 'scale_pos_weight': 2.3078477952300576, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 42 with value: 0.9756758431958836.
# [I 2025-06-19 11:03:02,985] Trial 43 finished with value: 0.9746739740025214 and parameters: {'lambda': 0.39205245707104897, 'alpha': 0.02555394911139477, 'subsample': 0.5332659400722494, 'colsample_bytree': 0.7286578660782511, 'max_depth': 10, 'eta': 0.26035802573927824, 'gamma': 1.570861397706627, 'scale_pos_weight': 3.0263755518919018, 'min_child_weight': 6, 'max_delta_step': 8}. Best is trial 42 with value: 0.9756758431958836.
# [I 2025-06-19 11:03:04,355] Trial 44 finished with value: 0.9758818415605827 and parameters: {'lambda': 0.9421545298809988, 'alpha': 0.036046161820006625, 'subsample': 0.6839175065845086, 'colsample_bytree': 0.7975241387881676, 'max_depth': 9, 'eta': 0.29992469001463407, 'gamma': 0.7849788388606183, 'scale_pos_weight': 2.185258886924526, 'min_child_weight': 7, 'max_delta_step': 9}. Best is trial 44 with value: 0.9758818415605827.
# [I 2025-06-19 11:03:05,735] Trial 45 finished with value: 0.9750998175500589 and parameters: {'lambda': 0.16084928112748795, 'alpha': 0.010713749562446785, 'subsample': 0.6767083010332191, 'colsample_bytree': 0.7032333371897933, 'max_depth': 9, 'eta': 0.2945419280296813, 'gamma': 0.9496263671779246, 'scale_pos_weight': 2.153924061532532, 'min_child_weight': 6, 'max_delta_step': 9}. Best is trial 44 with value: 0.9758818415605827.
# [I 2025-06-19 11:03:06,977] Trial 46 finished with value: 0.9732180521139392 and parameters: {'lambda': 0.06446066848699121, 'alpha': 0.013606780186379355, 'subsample': 0.6334738084639131, 'colsample_bytree': 0.9834656236288315, 'max_depth': 10, 'eta': 0.26335660006224365, 'gamma': 2.95627047834507, 'scale_pos_weight': 3.370547593261503, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 44 with value: 0.9758818415605827.
# [I 2025-06-19 11:03:08,343] Trial 47 finished with value: 0.9678409143914655 and parameters: {'lambda': 0.8177231275329915, 'alpha': 0.04133330579178541, 'subsample': 0.6943237748158282, 'colsample_bytree': 0.8058367401126707, 'max_depth': 9, 'eta': 0.11885277622725551, 'gamma': 4.477971558283034, 'scale_pos_weight': 5.584617225336493, 'min_child_weight': 6, 'max_delta_step': 9}. Best is trial 44 with value: 0.9758818415605827.
# [I 2025-06-19 11:03:09,309] Trial 48 finished with value: 0.9486367031296007 and parameters: {'lambda': 1.6147379784107028, 'alpha': 0.027911635152948682, 'subsample': 0.6080649883352547, 'colsample_bytree': 0.8814810855405232, 'max_depth': 3, 'eta': 0.06588035377001517, 'gamma': 2.1788027688098186, 'scale_pos_weight': 1.4968291140257302, 'min_child_weight': 5, 'max_delta_step': 9}. Best is trial 44 with value: 0.9758818415605827.
# [I 2025-06-19 11:03:10,271] Trial 49 finished with value: 0.9630830554265583 and parameters: {'lambda': 0.398243864361528, 'alpha': 0.017574651882909634, 'subsample': 0.487363010325745, 'colsample_bytree': 0.67866690745873, 'max_depth': 10, 'eta': 0.2858214391237742, 'gamma': 8.884189552489932, 'scale_pos_weight': 7.85223115078513, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 44 with value: 0.9758818415605827.

# %%
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.98      9137
#         True       0.71      0.84      0.77       861
#
#     accuracy                           0.96      9998
#    macro avg       0.85      0.90      0.87      9998
# weighted avg       0.96      0.96      0.96      9998

# %%
best_model_logistic
# Out:
# LogisticRegression(C=40.51488047924929, solver='liblinear',
#                    tol=0.0111978533083954)

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00010945, 0.00010945]),
#  array([0.        , 0.00116144, 0.21486643, 0.21486643, 0.22067364]),
#  array([       inf, 0.99999993, 0.99862694, 0.99862009, 0.99848374]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.9828797843943979

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
tpr
# Out:
# array([0.        , 0.00116144, 0.21486643, 0.21486643, 0.22067364,
#        0.22067364, 0.26945412, 0.26945412, 0.33565621, 0.33565621,
#        0.34146341, 0.34146341, 0.34843206, 0.34843206, 0.35656214,
#        0.35656214, 0.36469222, 0.36469222, 0.39372822, 0.39372822,
#        0.3960511 , 0.3960511 , 0.39721254, 0.39721254, 0.39953542,
#        0.39953542, 0.40069686, 0.40069686, 0.41579559, 0.41579559,
#        0.41811847, 0.41811847, 0.42044135, 0.42044135, 0.42392567,
#        0.42392567, 0.42624855, 0.42624855, 0.43089431, 0.43089431,
#        0.43554007, 0.43554007, 0.44018583, 0.44018583, 0.44367015,
#        0.44367015, 0.44483159, 0.44483159, 0.44599303, 0.44599303,
#        0.44715447, 0.44715447, 0.45876887, 0.45876887, 0.45993031,
#        0.45993031, 0.46225319, 0.46225319, 0.46457607, 0.46457607,
#        0.47154472, 0.47154472, 0.4738676 , 0.4738676 , 0.49245064,
#        0.49245064, 0.49361208, 0.49361208, 0.49593496, 0.49593496,
#        0.50174216, 0.50174216, 0.50522648, 0.50522648, 0.50754936,
#        0.50754936, 0.50987224, 0.50987224, 0.5203252 , 0.5203252 ,
#        0.52380952, 0.52380952, 0.52497096, 0.52497096, 0.53193961,
#        0.53193961, 0.53542393, 0.53542393, 0.53658537, 0.53658537,
#        0.54355401, 0.54355401, 0.54936121, 0.54936121, 0.55516841,
#        0.55516841, 0.56097561, 0.56097561, 0.56213705, 0.56213705,
#        0.56562137, 0.56562137, 0.56910569, 0.56910569, 0.57026713,
#        0.57026713, 0.57142857, 0.57142857, 0.57375145, 0.57375145,
#        0.57723577, 0.57723577, 0.58420441, 0.58420441, 0.58536585,
#        0.58536585, 0.59233449, 0.59233449, 0.59581882, 0.59581882,
#        0.5981417 , 0.5981417 , 0.60046458, 0.60046458, 0.60278746,
#        0.60278746, 0.60627178, 0.60627178, 0.60859466, 0.60859466,
#        0.61091754, 0.61091754, 0.6213705 , 0.6213705 , 0.62601626,
#        0.62601626, 0.62950058, 0.62950058, 0.63066202, 0.63066202,
